# %% [markdown]
# # Graph Fraud GNN — one-click run
#
# Clones the repo, installs it, and runs the demo end-to-end. **Runtime → Run all**.
#
# Runs on the free Colab CPU runtime — no API keys, no data downloads (all demo data is generated in code).

# %% [markdown]
# ### 1. Clone the repository

# %%
import os
if not os.path.isdir('/content/graph-fraud-gnn'):
    # !git clone -q https://github.com/akshay-birla-03/graph-fraud-gnn.git /content/graph-fraud-gnn
# %cd /content/graph-fraud-gnn

# %% [markdown]
# ### 2. Install

# %%
# Colab already ships PyTorch, which satisfies the torch dependency.
# !pip install -q -e .

# %% [markdown]
# ### 3. Run the demo

# %%
# !graphfraud
